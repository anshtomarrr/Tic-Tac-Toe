# %% [markdown]
# <a href="https://colab.research.google.com/github/anshtomarrr/Tic-Tac-Toe/blob/main/EDA_L1_Student_Copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview of Jupter Notebook

# %% [markdown]
# - Run a python command
# - Add some text
# - Add a heading

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Pulse check on linux commands

# %%
# !mkdir first_cloud_folder

# %%
# !ls
# Out:
# fir_cloud_folder  first_cloud_folder  sample_data

# %%
# !ls sample_data
# Out:
# ls: cannot access 'first_cloud_folder/sample_data': No such file or directory

# %% [markdown]
# `!gdown  "https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX" -O dummy_restaurants.csv`

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX" -O dummy_restaurants.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX
# To: /content/dummy_restaurants.csv
# 100% 1.50k/1.50k [00:00<00:00, 4.95MB/s]

# %%
# !ls
# Out:
# dummy_restaurants.csv  fir_cloud_folder  first_cloud_folder  sample_data

# %% [markdown]
# # Data loading

# %% [markdown]
# ```
# pandas.read_csv("https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX")
# ```

# %%
f = open("dummy_restaurants.csv","r")
f.readline().split(",")
# Out:
# ['name',
#  'city',
#  'rating',
#  'cost_for_two',
#  'cusine',
#  'online_order',
#  'table_reservation\n']

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
type(pd.read_csv("https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX"))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX")

# %%
df.shape
# Out:
# (20, 7)

# %%
df.head(2)
# Out:
#                           name       city  rating  cost_for_two  \
# 0       Gabbar's Bar & Kitchen    Kolkata     4.3          1500
# 1  Sardaar Ji De Chole Bhature  Delhi NCR     3.6           100
#
#                                     cusine online_order table_reservation
# 0  North Indian, Chinese, Mexican, Italian        False              True
# 1                             North Indian         True             False

# %% [markdown]
# # Data Overview

# %%
df.tail(5)
# Out:
#                                    name       city  rating  cost_for_two  \
# 15                             Monginis     Mumbai     3.4           200
# 16                    The Bohri Kitchen     Mumbai     4.8           600
# 17                       Italy in a Box     Mumbai     NaN           800
# 18                         PizzaExpress     Mumbai     4.3          1900
# 19  Artusi Ristorante in Piazza Horizon  Delhi NCR     4.3          3500
#
#                             cusine online_order table_reservation
# 15               Bakery, Fast Food         True             False
# 16  Mughlai, North Indian, Biryani          NaN               NaN
# 17            Italian, Continental         True             False
# 18                  Italian, Pizza         True              True
# 19                         Italian        False              True

# %%
df.sample()
# Out:
#                  name    city  rating  cost_for_two  \
# 16  The Bohri Kitchen  Mumbai     4.8           600
#
#                             cusine online_order table_reservation
# 16  Mughlai, North Indian, Biryani          NaN               NaN

# %%
df.describe()
# Out:
#           rating  cost_for_two
# count  18.000000     20.000000
# mean    3.850000    685.000000
# std     0.470607    807.057684
# min     3.300000    100.000000
# 25%     3.450000    200.000000
# 50%     3.750000    400.000000
# 75%     4.200000    762.500000
# max     4.800000   3500.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cost_for_two'].plot(kind='hist', bins=20, title='cost_for_two')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.describe(include="all")
# Out:
#                           name       city     rating  cost_for_two  \
# count                       20         20  18.000000     20.000000
# unique                      20          3        NaN           NaN
# top     Gabbar's Bar & Kitchen  Delhi NCR        NaN           NaN
# freq                         1          9        NaN           NaN
# mean                       NaN        NaN   3.850000    685.000000
# std                        NaN        NaN   0.470607    807.057684
# min                        NaN        NaN   3.300000    100.000000
# 25%                        NaN        NaN   3.450000    200.000000
# 50%                        NaN        NaN   3.750000    400.000000
# 75%                        NaN        NaN   4.200000    762.500000
# max                        NaN        NaN   4.800000   3500.000000
#
#                        cusine online_order table_reservation
# count                      20           18                18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               20 non-null     object
#  1   city               20 non-null     object
#  2   rating             18 non-null     float64
#  3   cost_for_two       20 non-null     int64
#  4   cusine             20 non-null     object
#  5   online_order       18 non-null     object
#  6   table_reservation  18 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.2+ KB

# %% [markdown]
# # Column Operations

# %%
df["rating"].min(),df["rating"].max()
# Out:
# (3.3, 4.8)

# %%
df["cost_for_two"].mean()
# Out:
# 685.0

# %%
df["city"].unique()
# Out:
# array(['Kolkata', 'Delhi NCR', 'Mumbai'], dtype=object)

# %%
df["city"].value_counts()
# Out:
# city
# Delhi NCR    9
# Mumbai       7
# Kolkata      4
# Name: count, dtype: int64

# %%
# expensive  = 0
# for cost in df["cost_for_two"]:
#   if cost >=1000:
#     expensive+=1
# print(expensive)

df["cost_for_two"]>=1000
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# Name: cost_for_two, dtype: bool

# %% [markdown]
# # Row Operations

# %%
df.iloc[0]
# Out:
# name                                  Gabbar's Bar & Kitchen
# city                                                 Kolkata
# rating                                                   4.3
# cost_for_two                                            1500
# cusine               North Indian, Chinese, Mexican, Italian
# online_order                                           False
# table_reservation                                       True
# Name: 0, dtype: object

# %%
df.iloc[1:4]
# Out:
#                           name       city  rating  cost_for_two  \
# 1  Sardaar Ji De Chole Bhature  Delhi NCR     3.6           100
# 2                  YellowKrust  Delhi NCR     3.8           400
# 3              Hungry Minister  Delhi NCR     3.7           400
#
#                                      cusine online_order table_reservation
# 1                              North Indian         True             False
# 2                          Bakery, Desserts        False             False
# 3  Continental, Mexican, Fast Food, Chinese         True             False

# %%
df[["rating","name"]]
# Out:
#     rating                                 name
# 0      4.3               Gabbar's Bar & Kitchen
# 1      3.6          Sardaar Ji De Chole Bhature
# 2      3.8                          YellowKrust
# 3      3.7                      Hungry Minister
# 4      3.3                      Night Food Xprs
# 5      4.8                HOP House of Proteins
# 6      3.4        Daana Paani Family Restaurant
# 7      3.8                      Swad Restaurant
# 8      3.7                       Chai Peeni Hai
# 9      3.8                       Baskin Robbins
# 10     NaN                               Spirit
# 11     3.9                           Purple Box
# 12     3.4                            Mio Amore
# 13     3.7                          Talli Pangs
# 14     3.3                           Just Baked
# 15     3.4                             Monginis
# 16     4.8                    The Bohri Kitchen
# 17     NaN                       Italy in a Box
# 18     4.3                         PizzaExpress
# ...

# %%
df[["rating"]]
# Out:
#     rating
# 0      4.3
# 1      3.6
# 2      3.8
# 3      3.7
# 4      3.3
# 5      4.8
# 6      3.4
# 7      3.8
# 8      3.7
# 9      3.8
# 10     NaN
# 11     3.9
# 12     3.4
# 13     3.7
# 14     3.3
# 15     3.4
# 16     4.8
# 17     NaN
# 18     4.3
# 19     4.3

# %%
df["rating"]
# Out:
# 0     4.3
# 1     3.6
# 2     3.8
# 3     3.7
# 4     3.3
# 5     4.8
# 6     3.4
# 7     3.8
# 8     3.7
# 9     3.8
# 10    NaN
# 11    3.9
# 12    3.4
# 13    3.7
# 14    3.3
# 15    3.4
# 16    4.8
# 17    NaN
# 18    4.3
# 19    4.3
# Name: rating, dtype: float64

# %% [markdown]
# # Lets get a bit real :)

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1qgMZdOpZ_KJAgqc46WW5pvG7xgkJ2jQ6" -O restaurants_all.csv
import pandas as pd # explain pd here
df = pd.read_csv('restaurants_all.csv')
df.head(5)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1qgMZdOpZ_KJAgqc46WW5pvG7xgkJ2jQ6
# From (redirected): https://drive.google.com/uc?export=download&id=1qgMZdOpZ_KJAgqc46WW5pvG7xgkJ2jQ6&confirm=t&uuid=a95c8741-a893-4e32-aa75-5cd5613037aa
# To: /content/restaurants_all.csv
# 100% 190M/190M [00:03<00:00, 50.3MB/s]
#                                           zomato_url  \
# 0  https://www.zomato.com/ncr/sainik-food-pandav-...
# 1  https://www.zomato.com/mumbai/kunals-creamery-...
# 2  https://www.zomato.com/ncr/brij-palace-restaur...
# 3  https://www.zomato.com/ncr/sahib-hotel-paharga...
# 4  https://www.zomato.com/kolkata/chunkys-shibpur...
#
#                         name       city          area  rating  rating_count  \
# 0                Sainik Food  Delhi NCR  Pandav Nagar     3.2          21.0
# 1  Kunal's Creamery & Eatery     Mumbai     Ambernath     3.6          51.0
# 2     Brij Palace Restaurant  Delhi NCR        Jasola     NaN           NaN
# ...

# %% [markdown]
# #### How many restaurnts data do we have?

# %% [markdown]
# #### How many cities data do we have?

# %% [markdown]
# #### How many restaurants in Mumbai in the dataset?

# %% [markdown]
# ### Which is most costly Mumbai or Delhi NCR?

# %% [markdown]
# #### I walk into a random restaurant in Delhi, what is the chance that it is expensive?
